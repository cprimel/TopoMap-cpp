# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('../build/output', header=None)
data_normalized = pd.read_csv('../build/output_normalized', header=None)
# Uncomment for iris labeling
#labels = pd.read_csv('../data/bezdekIris.data', header=None)
#labels = pd.Categorical(labels[4]).codes
#print(len(data), len(data_normalized),len(labels))

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(16,8))

ax1.scatter(data[0],data[1])
ax1.set_title("FICO data - not normalized")
ax2.scatter(data_normalized[0],data_normalized[1])
ax2.set_title("FICO data - normalized")
# Out:
# Text(0.5, 1.0, 'FICO data - normalized')

# %%
data

# %%
data_normalized
